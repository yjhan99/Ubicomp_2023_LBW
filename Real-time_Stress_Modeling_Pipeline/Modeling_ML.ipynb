# %%
import sys
import os
import dbfread
from dbfread import DBF
import dbf
from glob import glob 
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc, font_manager
import plotly as py
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
from ipywidgets import interact
import seaborn as sns
from datetime import datetime, timedelta
import time
import pickle
from collections import Counter
from tqdm import tqdm
import plotly.express as px
import datetime
from datetime import datetime
import matplotlib.font_manager as fm
# font_list = fm.findSystemFonts(fontpaths=None, fontext = 'ttf')
from matplotlib import font_manager
# font_path = "C:/Windows/Fonts/NGULIM.TTF"
# font = font_manager.FontProperties(fname=font_path).get_name()
# rc('font', family=font)
rc('font', family='AppleGothic')
import heartpy as hp
import sklearn
import sklearn.preprocessing
from sklearn.preprocessing import normalize
import pywt

# %%
import pandas as pd

from scipy.interpolate import CubicSpline
from scipy.signal import medfilt

from scipy.interpolate import UnivariateSpline
from scipy.signal import welch, periodogram

import heartpy as hp

import warnings

warnings.filterwarnings('ignore', category=UserWarning)

# %% [markdown]
# ## Data Loading

# %%
WEAROS_PPG_DATA = pd.read_csv('../WearOS_Dataset/PPG_Dataset.csv')
WEAROS_PPG_DATA.head()
# Out:
#       timestamp           ppg  pnum  condition
# 0  1.671078e+09  3.017970e-39     1  baseline1
# 1  1.671078e+09  3.017630e-39     1  baseline1
# 2  1.671078e+09  3.018150e-39     1  baseline1
# 3  1.671078e+09  3.018690e-39     1  baseline1
# 4  1.671078e+09  3.019180e-39     1  baseline1

# %%
CONDITION_TIMESTAMP = pd.read_csv('../WearOS_Dataset/condition_timestamp.csv')
CONDITION_TIMESTAMP.head()
# Out:
#   condition     timestamp  pnum
# 0  b1_start  1.671078e+09     1
# 1    b1_end  1.671078e+09     1
# 2  b2_start  1.671078e+09     1
# 3    b2_end  1.671078e+09     1
# 4   s_start  1.671079e+09     1

# %%
pnum_list = range(1,13,1)
cond_list = ['baseline1', 'baseline2', 'stress']

# %% [markdown]
# # Signal Preprocessing & Peak Detection & Artifact Removal

# %%
# WEAROS_PPG_DATA['filtered_ppg'] = hp.filter_signal(np.array(WEAROS_PPG_DATA.loc[:,'ppg']), cutoff=[0.8,3.5], sample_rate=25, filtertype='bandpass')


PP_INTERVAL_PROCESSED = pd.DataFrame()

for pnum in pnum_list:
    start_timestamp = CONDITION_TIMESTAMP.loc[(CONDITION_TIMESTAMP['pnum']==pnum) & (CONDITION_TIMESTAMP['condition'].str.contains('start')), 'timestamp']
    end_timestamp = CONDITION_TIMESTAMP.loc[(CONDITION_TIMESTAMP['pnum']==pnum) & (CONDITION_TIMESTAMP['condition'].str.contains('end')), 'timestamp']

    # Cut data by pnum
    WEAROS_PPG_DATA_p = WEAROS_PPG_DATA.loc[WEAROS_PPG_DATA['pnum'] == pnum]
    WEAROS_PPG_DATA_p = WEAROS_PPG_DATA_p.reset_index(drop=True)

    # Filtering
    WEAROS_PPG_DATA_p['filtered_ppg'] = hp.filter_signal(np.array(WEAROS_PPG_DATA_p.loc[:,'ppg']), order=3, cutoff=[0.8,3.5], sample_rate=25, filtertype='bandpass')

    for cond, cond_start_timestamp, cond_end_timestamp in zip(cond_list, start_timestamp, end_timestamp):
        # Cut data by condition
        WEAROS_PPG_DATA_cond = WEAROS_PPG_DATA_p.loc[WEAROS_PPG_DATA_p['condition'] == cond]
        WEAROS_PPG_DATA_cond = WEAROS_PPG_DATA_cond.reset_index(drop=True)

        # Outlier Removal
        WEAROS_PPG_DATA_cond['filtered_and_outlier_removed_ppg'] = hp.datautils.outliers_modified_z(np.array(WEAROS_PPG_DATA_cond['filtered_ppg']))[0]     

        # Peak Detection
        PP_INTERVAL = pd.DataFrame()
        input = WEAROS_PPG_DATA_cond['filtered_and_outlier_removed_ppg']
        working_data, measures = hp.process(input, sample_rate=25)
        PP_INTERVAL['RR_list'] = working_data['RR_list']
        timestamp= []
        for peak in working_data['peaklist'][:-1]:
            timestamp.append(WEAROS_PPG_DATA_cond.iloc[peak, 0])
        PP_INTERVAL['timestamp'] = timestamp

        # Chunking-based Correction
        PP_INTERVAL = PP_INTERVAL.loc[(PP_INTERVAL['RR_list'] > 300) & (PP_INTERVAL['RR_list'] < 1500)]
        PP_INTERVAL_PROCESSED_1 = pd.DataFrame()
        chunk_start = cond_start_timestamp
        while True:
            chunk_mid = chunk_start + 4
            chunk_end = chunk_start + 8
            chunk_1 = PP_INTERVAL.loc[(PP_INTERVAL['timestamp'] > chunk_start) & (PP_INTERVAL['timestamp'] < chunk_mid)]
            mean_rr = chunk_1['RR_list'].mean()
            chunk_2 = PP_INTERVAL.loc[(PP_INTERVAL['timestamp'] > chunk_mid) & (PP_INTERVAL['timestamp'] < chunk_end)]
            chunk_2 = chunk_2.loc[(chunk_2['RR_list'] > (mean_rr - 150)) & (chunk_2['RR_list'] < (mean_rr + 150))]
            PP_INTERVAL_PROCESSED_1 = pd.concat([PP_INTERVAL_PROCESSED_1, chunk_2], ignore_index=True)
            chunk_start = chunk_mid
            if (chunk_start + 4) >= cond_end_timestamp:
                break
        PP_INTERVAL_PROCESSED_2 = pd.DataFrame(columns=['RR_list','timestamp'])
        for idx in range(0,len(PP_INTERVAL_PROCESSED_1)-2):
            start = PP_INTERVAL_PROCESSED_1.iloc[idx]
            mid = PP_INTERVAL_PROCESSED_1.iloc[idx+1]
            PP_INTERVAL_PROCESSED_2.loc[len(PP_INTERVAL_PROCESSED_2)] = mid
            end = PP_INTERVAL_PROCESSED_1.iloc[idx+2]
            if (end['timestamp']-mid['timestamp']) > 2:
                gap = (end['timestamp']-mid['timestamp'])*1000
                peak_num = int((2*gap) // (end['RR_list']+start['RR_list']))
                rr = gap // (peak_num+1)
                for i in range(peak_num):
                    row = {'RR_list': rr, 'timestamp': mid['timestamp']+(rr*(i+1))/1000}
                    PP_INTERVAL_PROCESSED_2.loc[len(PP_INTERVAL_PROCESSED_2)] = row

        # Filtering-based Correction
        if (len(PP_INTERVAL_PROCESSED_2) > 2):
            med_filt = medfilt(PP_INTERVAL_PROCESSED_2['RR_list'], kernel_size=7)
            PP_INTERVAL_PROCESSED_2['med_filt'] = med_filt
            wrong = PP_INTERVAL_PROCESSED_2.loc[abs(PP_INTERVAL_PROCESSED_2['RR_list'] - PP_INTERVAL_PROCESSED_2['med_filt']) > 150]
            wrong_idx = PP_INTERVAL_PROCESSED_2.index.isin(list(wrong.index))
            cs = CubicSpline(PP_INTERVAL_PROCESSED_2[~wrong_idx]['timestamp'], PP_INTERVAL_PROCESSED_2[~wrong_idx]['RR_list'])
            new_rr = np.linspace(PP_INTERVAL_PROCESSED_2[~wrong_idx]['timestamp'].min(), PP_INTERVAL_PROCESSED_2[~wrong_idx]['timestamp'].max(), len(PP_INTERVAL_PROCESSED_2))
            PP_INTERVAL_PROCESSED_2['RR_list'] = cs(new_rr)

        # Galaxy Final Merge
        PP_INTERVAL_PROCESSED_2['pnum'] = pnum
        PP_INTERVAL_PROCESSED_2['cond'] = cond
        PP_INTERVAL_PROCESSED = pd.concat([PP_INTERVAL_PROCESSED, PP_INTERVAL_PROCESSED_2], ignore_index=True)

# %%
PP_INTERVAL_PROCESSED
# Out:
#          RR_list     timestamp  med_filt  pnum       cond
# 0     720.000000  1.671078e+09     720.0     1  baseline1
# 1     760.318172  1.671078e+09     760.0     1  baseline1
# 2     799.323354  1.671078e+09     760.0     1  baseline1
# 3     802.807198  1.671078e+09     760.0     1  baseline1
# 4     766.726167  1.671078e+09     800.0     1  baseline1
# ...          ...           ...       ...   ...        ...
# 7717  601.857888  1.671673e+09     600.0    12     stress
# 7718  597.503495  1.671673e+09     600.0    12     stress
# 7719  638.731519  1.671673e+09     600.0    12     stress
# 7720  640.424137  1.671673e+09     600.0    12     stress
# 7721  600.000000  1.671673e+09     600.0    12     stress
#
# [7722 rows x 5 columns]

# %% [markdown]
# # Feature Extraction

# %%
def calc_ts_measures(rr_list, rr_diff, rr_sqdiff, measures={}, working_data={}):
    '''
    Function that calculates the time-series HRV measurements.
    '''
    measures['bpm'] = 60000 / np.mean(rr_list)
    measures['ibi'] = np.mean(rr_list)

    measures['sdnn'] = np.std(rr_list)
    measures['sdsd'] = np.std(rr_diff)
    measures['rmssd'] = np.sqrt(np.mean(rr_sqdiff))
    nn20 = rr_diff[np.where(rr_diff > 20.0)]
    nn50 = rr_diff[np.where(rr_diff > 50.0)]
    working_data['nn50'] = nn50
    try:
        measures['pnn50'] = float(len(nn50)) / float(len(rr_diff))
    except:
        measures['pnn50'] = np.nan

    return working_data, measures

def calc_fd_measures(rr_list, method='welch', welch_wsize=240, square_spectrum=False, measures={}, degree_smoothing_spline=3):
    '''
    Function that calculates the frequency-domain HRV measurements.
    '''
    if len(rr_list) <= 1:
        measures['lf'] = np.nan
        measures['hf'] = np.nan
        measures['lf_hf'] = np.nan
        return measures

    rr_x = np.cumsum(rr_list)

    resamp_factor = 4
    datalen = int((len(rr_x) - 1)*resamp_factor)
    rr_x_new = np.linspace(int(rr_x[0]), int(rr_x[-1]), datalen)

    if len(rr_x) > degree_smoothing_spline:
        interpolation_func = UnivariateSpline(rr_x, rr_list, k=degree_smoothing_spline)
        rr_interp = interpolation_func(rr_x_new)

        # RR-list in units of ms, with the sampling rate at 1 sample per beat
        dt = np.mean(rr_list) / 1000  # in sec
        fs = 1 / dt  # about 1.1 Hz; 50 BPM would be 0.83 Hz, just enough to get the max of the HF band at 0.4 Hz according to Nyquist
        fs_new = fs * resamp_factor

        # compute PSD (one-sided, units of ms^2/Hz)
        if method == 'fft':
            frq = np.fft.fftfreq(datalen, d=(1 / fs_new))
            frq = frq[range(int(datalen / 2))]
            Y = np.fft.fft(rr_interp) / datalen
            Y = Y[range(int(datalen / 2))]
            psd = np.power(Y, 2)

        elif method == 'periodogram':
            frq, psd = periodogram(rr_interp, fs=fs_new)

        elif method == 'welch':
            # nperseg should be based on trade-off btw temporal res and freq res
            nperseg = welch_wsize * fs_new
            if nperseg >= len(rr_x_new):  # if nperseg is larger than the available data segment
                nperseg = len(rr_x_new)  # set it to length of data segment to prevent scipy warnings
            frq, psd = welch(rr_interp, fs=fs_new, nperseg=nperseg)
        else:
            raise ValueError("specified method incorrect, use 'fft', 'periodogram' or 'welch'")

        df = frq[1] - frq[0]
        measures['lf'] = np.trapz(abs(psd[(frq >= 0.04) & (frq < 0.15)]), dx=df)
        measures['hf'] = np.trapz(abs(psd[(frq >= 0.15) & (frq < 0.4)]), dx=df)
        measures['lf_hf'] = measures['lf'] / measures['hf']

    else:
        measures['lf'] = np.nan
        measures['hf'] = np.nan
        measures['lf_hf'] = np.nan

    return measures

# %%
window_size = 60
stepsize = 0.25

HRV_FEATURES_DATAFRAME = pd.DataFrame(columns=['ibi','bpm','sdnn','rmssd','pnn50','lf','hf','lf_hf','pnum','cond'])

for pnum in pnum_list:
    for cond in cond_list:
        galaxy = PP_INTERVAL_PROCESSED.loc[(PP_INTERVAL_PROCESSED['pnum']==pnum)&(PP_INTERVAL_PROCESSED['cond']==cond)]
        window_start = galaxy['timestamp'].min()
        add_g = pd.DataFrame(columns=['ibi','bpm','sdnn','rmssd','pnn50','lf','hf','lf_hf'])
        while True:
            window_end = window_start + window_size
            window = galaxy.loc[(galaxy['timestamp'] > window_start) & (galaxy['timestamp'] < window_end)]
            rr_list = window['RR_list']
            rr_diff = np.abs(np.diff(rr_list))
            rr_sqdiff = np.power(rr_diff, 2)
            wd_ts, m_ts = calc_ts_measures(rr_list, rr_diff, rr_sqdiff)
            m = calc_fd_measures(rr_list=np.asarray(rr_list), measures=m_ts)
            add_g.loc[len(add_g)] = m
            window_start += stepsize
            if (window_start + 60) > galaxy['timestamp'].max():
                break
        add_g['pnum'] = pnum
        add_g['cond'] = cond
        HRV_FEATURES_DATAFRAME = pd.concat([HRV_FEATURES_DATAFRAME, add_g], ignore_index=True)

HRV_FEATURES_DATAFRAME.head()
# Out:
#           ibi        bpm       sdnn      rmssd     pnn50           lf  \
# 0  776.518957  77.267914  62.179649  50.593609  0.270270  1329.770144
# 1  776.498793  77.269920  61.769464  50.416174  0.266667  1347.546972
# 2  776.498793  77.269920  61.769464  50.416174  0.266667  1347.546972
# 3  776.714535  77.248458  62.151446  50.552741  0.270270  1389.742245
# 4  775.897449  77.329807  62.145378  50.696151  0.280000  1407.374422
#
#             hf     lf_hf pnum       cond
# 0  2273.742878  0.584838    1  baseline1
# 1  2312.610569  0.582695    1  baseline1
# 2  2312.610569  0.582695    1  baseline1
# 3  2220.806877  0.625783    1  baseline1
# 4  2259.983299  0.622737    1  baseline1

# %% [markdown]
# # Stress Detection Model

# %% [markdown]
# ## Data Normalization

# %%
from sklearn.preprocessing import StandardScaler

feature_list = ['ibi','bpm','sdnn','rmssd','pnn50','lf','hf','lf_hf']
HRV_FEATURES_DATAFRAME_NORMALIZED = pd.DataFrame(columns=feature_list)

for pnum in pnum_list:
    HRV_FEATURES_DATAFRAME_p = HRV_FEATURES_DATAFRAME.loc[HRV_FEATURES_DATAFRAME['pnum']==pnum]
    scaled = StandardScaler().fit_transform(HRV_FEATURES_DATAFRAME_p[feature_list])
    scaled_df = pd.DataFrame(scaled, index=HRV_FEATURES_DATAFRAME_p.index, columns=feature_list)
    HRV_FEATURES_DATAFRAME_NORMALIZED = pd.concat([HRV_FEATURES_DATAFRAME_NORMALIZED, scaled_df], ignore_index=True)

HRV_FEATURES_DATAFRAME_NORMALIZED = HRV_FEATURES_DATAFRAME_NORMALIZED.reset_index(drop=True)
HRV_FEATURES_DATAFRAME_NORMALIZED['cond'] = list(HRV_FEATURES_DATAFRAME['cond'])        
HRV_FEATURES_DATAFRAME_NORMALIZED['pnum'] = list(HRV_FEATURES_DATAFRAME['pnum'])
HRV_FEATURES_DATAFRAME_NORMALIZED['label'] = HRV_FEATURES_DATAFRAME['cond'].apply(lambda x: 1 if 'stress' in x else 0)

HRV_FEATURES_DATAFRAME_NORMALIZED.head()
# Out:
#         ibi       bpm      sdnn     rmssd     pnn50        lf        hf  \
# 0  2.052504 -1.892195 -0.378220  0.182108  0.440094  0.457753  0.066449
# 1  2.052089 -1.891873 -0.396956  0.161832  0.346316  0.480915  0.070308
# 2  2.052089 -1.891873 -0.396956  0.161832  0.346316  0.480915  0.070308
# 3  2.056536 -1.895312 -0.379508  0.177437  0.440094  0.535892  0.061193
# 4  2.039691 -1.882278 -0.379785  0.193825  0.693297  0.558865  0.065083
#
#       lf_hf       cond  pnum  label
# 0 -0.641665  baseline1     1      0
# 1 -0.645909  baseline1     1      0
# 2 -0.645909  baseline1     1      0
# 3 -0.560552  baseline1     1      0
# 4 -0.566586  baseline1     1      0

# %% [markdown]
# ## Simple Threshold-based Model

# %%
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score

def calculate_best_threshold(INPUT_DATAFRAME):
    best_threshold_dict = {}

    for idx, feature in enumerate(feature_list):
        min = INPUT_DATAFRAME[feature].min()
        max = INPUT_DATAFRAME[feature].max()

        fpr_list, tpr_list, gmeans_list = [], [], []
        threshold_list = np.linspace(min, max, 100)

        for threshold in threshold_list:
            MODEL_DEVICE = pd.DataFrame(columns=['label',feature])

            MODEL_DEVICE['label'] = INPUT_DATAFRAME['label']
            if feature in ['ibi','sdnn','rmssd','pnn50','hf']:
                MODEL_DEVICE[feature] = INPUT_DATAFRAME[feature].apply(lambda x: 0 if x > threshold else 1)
            else:
                MODEL_DEVICE[feature] = INPUT_DATAFRAME[feature].apply(lambda x: 0 if x < threshold else 1)

            cf = confusion_matrix(list(MODEL_DEVICE['label']), list(MODEL_DEVICE[feature]))
            fpr = cf[0][1] / (cf[0][1] + cf[0][0])
            tpr = cf[1][1] / (cf[1][1] + cf[1][0])

            fpr_list.append(fpr)
            tpr_list.append(tpr)
            gmeans_list.append(np.sqrt(tpr * (1-fpr)))

        ix = np.argmax(gmeans_list)
        best_threshold = threshold_list[ix]

        best_threshold_dict[feature] = best_threshold

    return best_threshold_dict

def threshold_model(INPUT_DATAFRAME):
    FEATURES = INPUT_DATAFRAME[feature_list]
    LABELS_AVAL = INPUT_DATAFRAME['label']
    PIDS = INPUT_DATAFRAME['pnum']

    RESULTS_AVAL, MODELS_AVAL, TRAIN_SETS_AVAL = [], {}, {}

    splitter = LeaveOneGroupOut()

    for I_train, I_test in splitter.split(FEATURES, LABELS_AVAL, PIDS):    
        X_train, X_test = FEATURES.iloc[I_train], FEATURES.iloc[I_test] 
        y_train, y_test = LABELS_AVAL.iloc[I_train], LABELS_AVAL.iloc[I_test]
        test_name = np.unique(PIDS[I_test])[0]

        input = pd.concat([X_train, y_train], axis=1)
        clf = calculate_best_threshold(input)

        for feature in feature_list:
            best_threshold = clf[feature]
            
            if feature in ['ibi', 'sdnn', 'rmssd', 'pnn50', 'hf']:
                y_pred = X_test[feature].apply(lambda x: 0 if x > best_threshold else 1)
            else:
                y_pred = X_test[feature].apply(lambda x: 0 if x < best_threshold else 1)

            RESULTS_AVAL.append({
                'feature': feature,
                'accuracy': accuracy_score(y_test, y_pred),
                'f1_score': f1_score(y_test, y_pred),
            })

            MODELS_AVAL[test_name] = clf
            TRAIN_SETS_AVAL[test_name] = X_train

    return RESULTS_AVAL

# %%
RESULTS_DATAFRAME = threshold_model(HRV_FEATURES_DATAFRAME_NORMALIZED)
print(pd.DataFrame(RESULTS_DATAFRAME).groupby(by='feature').mean())
print(pd.DataFrame(RESULTS_DATAFRAME).groupby(by='feature').std())
# Out:
#          accuracy  f1_score
# feature
# bpm      0.791737  0.806828
# hf       0.389983  0.063780
# ibi      0.796143  0.809909
# lf       0.479136  0.309937
# lf_hf    0.525358  0.580969
# pnn50    0.428790  0.508402
# rmssd    0.364935  0.414337
# sdnn     0.411928  0.512379
#          accuracy  f1_score
# feature
# bpm      0.234654  0.226506
# hf       0.040477  0.150436
# ibi      0.235497  0.230540
# lf       0.132100  0.338438
# lf_hf    0.108359  0.095245
# pnn50    0.126482  0.091124
# rmssd    0.173937  0.171082
# sdnn     0.176699  0.141203

# %% [markdown]
# ## Machine-Learning Model

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit, LeaveOneGroupOut
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score

def major_voting(INPUT_DATAFRAME):
    DATA_SET = INPUT_DATAFRAME
    RESULTS_AVAL = []

    for pnum in pnum_list:
        y_true = list(DATA_SET.loc[DATA_SET['pnum']==pnum, 'label'])
        print(np.mean(y_true))
        if np.mean(y_true) > 0.5:
            y_pred = [1] * len(y_true)
        else:    
            y_pred = [0] * len(y_true)
        
        RESULTS_AVAL.append({
                'accuracy': accuracy_score(y_true, y_pred),
                'f1_score': f1_score(y_true, y_pred)
            })
        
    return RESULTS_AVAL

def dt_model(INPUT_DATAFRAME):
    DATA_SET = INPUT_DATAFRAME

    FEATURES = DATA_SET[feature_list]
    LABELS_AVAL = DATA_SET['label']
    PIDS = DATA_SET['pnum']

    RESULTS_AVAL, MODELS_AVAL, TRAIN_SETS_AVAL = [], {}, {}

    splitter = LeaveOneGroupOut()

    for I_train, I_test in splitter.split(FEATURES, LABELS_AVAL, PIDS):    
        X_train, X_test = FEATURES.iloc[I_train], FEATURES.iloc[I_test] 
        y_train, y_test = LABELS_AVAL.iloc[I_train], LABELS_AVAL.iloc[I_test]
        test_name = np.unique(PIDS[I_test])[0]
        
        inner_splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
        I_train, I_eval = next(inner_splitter.split(X_train, y_train))
        X_train, X_eval = X_train.iloc[I_train], X_train.iloc[I_eval]
        y_train, y_eval = y_train.iloc[I_train], y_train.iloc[I_eval]

        clf = DecisionTreeClassifier(criterion='entropy', min_samples_split=20)
        
        clf.fit(X_train, y_train)

        # # General approach
        # y_pred = clf.predict(X_test)
        # y_prob = clf.predict_proba(X_test)[:, 1]

        # Use of V.Mishra's two-layer approach https://dl.acm.org/doi/pdf/10.1145/3361562        
        CLF_THRESHOLD = 0.5
        GAMMA = 0.33
        DELTA = 0.86
        
        D, yi_1 = [], None
        X_test = X_test.reset_index(drop=True)
        for idx in X_test.index:
            xi = clf.predict(pd.DataFrame(X_test.iloc[idx, (X_test.columns != 'pnum') & (X_test.columns != 'cond') & (X_test.columns != 'label')]).T)[0]

            if not D or D[-1] == xi:
                yi = xi
            else:
                yi = GAMMA*(1 - yi_1)*xi + DELTA*yi_1*(1 - xi) + yi_1*xi

            Di = 1 if yi >= CLF_THRESHOLD else 0
            D.append(Di)
            yi_1 = yi

        res = filter(lambda x: x[0] != -1, zip(y_test.values, D))
        y_test, y_pred = zip(*res)

        RESULTS_AVAL.append({
            'accuracy': accuracy_score(y_test, y_pred),
            'f1_score': f1_score(y_test, y_pred)

        })
        MODELS_AVAL[test_name] = clf
        TRAIN_SETS_AVAL[test_name] = X_train

    return RESULTS_AVAL

def rf_model(INPUT_DATAFRAME):
    DATA_SET = INPUT_DATAFRAME

    FEATURES = DATA_SET[feature_list]
    LABELS_AVAL = DATA_SET['label']
    PIDS = DATA_SET['pnum']

    RESULTS_AVAL, MODELS_AVAL, TRAIN_SETS_AVAL = [], {}, {}

    splitter = LeaveOneGroupOut()

    for I_train, I_test in splitter.split(FEATURES, LABELS_AVAL, PIDS):    
        X_train, X_test = FEATURES.iloc[I_train], FEATURES.iloc[I_test] 
        y_train, y_test = LABELS_AVAL.iloc[I_train], LABELS_AVAL.iloc[I_test]
        test_name = np.unique(PIDS[I_test])[0]
        
        inner_splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
        I_train, I_eval = next(inner_splitter.split(X_train, y_train))
        X_train, X_eval = X_train.iloc[I_train], X_train.iloc[I_eval]
        y_train, y_eval = y_train.iloc[I_train], y_train.iloc[I_eval]
        
        clf = RandomForestClassifier(criterion='gini', min_samples_split=10, n_estimators=100)
        
        clf.fit(X_train, y_train)

        # # General approach
        # y_pred = clf.predict(X_test)
        # y_prob = clf.predict_proba(X_test)[:, 1]

        # Use of V.Mishra's two-layer approach https://dl.acm.org/doi/pdf/10.1145/3361562        
        CLF_THRESHOLD = 0.5
        GAMMA = 0.33
        DELTA = 0.86
        
        D, yi_1 = [], None
        X_test = X_test.reset_index(drop=True)
        for idx in X_test.index:
            xi = clf.predict(pd.DataFrame(X_test.iloc[idx, (X_test.columns != 'pnum') & (X_test.columns != 'cond') & (X_test.columns != 'label')]).T)[0]

            if not D or D[-1] == xi:
                yi = xi
            else:
                yi = GAMMA*(1 - yi_1)*xi + DELTA*yi_1*(1 - xi) + yi_1*xi

            Di = 1 if yi >= CLF_THRESHOLD else 0
            D.append(Di)
            yi_1 = yi

        res = filter(lambda x: x[0] != -1, zip(y_test.values, D))
        y_test, y_pred = zip(*res)

        RESULTS_AVAL.append({
            'accuracy': accuracy_score(y_test, y_pred),
            'f1_score': f1_score(y_test, y_pred)
        })
        MODELS_AVAL[test_name] = clf
        TRAIN_SETS_AVAL[test_name] = X_train

    return RESULTS_AVAL

def ab_model(INPUT_DATAFRAME):
    DATA_SET = INPUT_DATAFRAME

    FEATURES = DATA_SET[feature_list]
    LABELS_AVAL = DATA_SET['label']
    PIDS = DATA_SET['pnum']

    RESULTS_AVAL, MODELS_AVAL, TRAIN_SETS_AVAL = [], {}, {}

    splitter = LeaveOneGroupOut()

    for I_train, I_test in splitter.split(FEATURES, LABELS_AVAL, PIDS):    
        X_train, X_test = FEATURES.iloc[I_train], FEATURES.iloc[I_test] 
        y_train, y_test = LABELS_AVAL.iloc[I_train], LABELS_AVAL.iloc[I_test]
        test_name = np.unique(PIDS[I_test])[0]
        
        inner_splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
        I_train, I_eval = next(inner_splitter.split(X_train, y_train))
        X_train, X_eval = X_train.iloc[I_train], X_train.iloc[I_eval]
        y_train, y_eval = y_train.iloc[I_train], y_train.iloc[I_eval]

        dt = DecisionTreeClassifier(criterion='entropy', min_samples_split=20)
        clf = AdaBoostClassifier(estimator=dt, n_estimators=100, algorithm='SAMME.R')
        
        clf.fit(X_train, y_train)

        # # General approach
        # y_pred = clf.predict(X_test)
        # y_prob = clf.predict_proba(X_test)[:, 1]

        # Use of V.Mishra's two-layer approach https://dl.acm.org/doi/pdf/10.1145/3361562        
        CLF_THRESHOLD = 0.5
        GAMMA = 0.33
        DELTA = 0.86
        
        D, yi_1 = [], None
        X_test = X_test.reset_index(drop=True)
        for idx in X_test.index:
            xi = clf.predict(pd.DataFrame(X_test.iloc[idx, (X_test.columns != 'pnum') & (X_test.columns != 'cond') & (X_test.columns != 'label')]).T)[0]

            if not D or D[-1] == xi:
                yi = xi
            else:
                yi = GAMMA*(1 - yi_1)*xi + DELTA*yi_1*(1 - xi) + yi_1*xi

            Di = 1 if yi >= CLF_THRESHOLD else 0
            D.append(Di)
            yi_1 = yi

        res = filter(lambda x: x[0] != -1, zip(y_test.values, D))
        y_test, y_pred = zip(*res)

        RESULTS_AVAL.append({
            'accuracy': accuracy_score(y_test, y_pred),
            'f1_score': f1_score(y_test, y_pred)
        })
        MODELS_AVAL[test_name] = clf
        TRAIN_SETS_AVAL[test_name] = X_train

    return RESULTS_AVAL

def lda_model(INPUT_DATAFRAME):
    DATA_SET = INPUT_DATAFRAME

    FEATURES = DATA_SET[feature_list]
    LABELS_AVAL = DATA_SET['label']
    PIDS = DATA_SET['pnum']

    RESULTS_AVAL, MODELS_AVAL, TRAIN_SETS_AVAL = [], {}, {}

    splitter = LeaveOneGroupOut()

    for I_train, I_test in splitter.split(FEATURES, LABELS_AVAL, PIDS):    
        X_train, X_test = FEATURES.iloc[I_train], FEATURES.iloc[I_test] 
        y_train, y_test = LABELS_AVAL.iloc[I_train], LABELS_AVAL.iloc[I_test]
        test_name = np.unique(PIDS[I_test])[0]
        
        inner_splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
        I_train, I_eval = next(inner_splitter.split(X_train, y_train))
        X_train, X_eval = X_train.iloc[I_train], X_train.iloc[I_eval]
        y_train, y_eval = y_train.iloc[I_train], y_train.iloc[I_eval]

        clf = LinearDiscriminantAnalysis()
        
        clf.fit(X_train, y_train)

        # # General approach
        # y_pred = clf.predict(X_test)
        # y_prob = clf.predict_proba(X_test)[:, 1]

        # Use of V.Mishra's two-layer approach https://dl.acm.org/doi/pdf/10.1145/3361562        
        CLF_THRESHOLD = 0.5
        GAMMA = 0.33
        DELTA = 0.86
        
        D, yi_1 = [], None
        X_test = X_test.reset_index(drop=True)
        for idx in X_test.index:
            xi = clf.predict(pd.DataFrame(X_test.iloc[idx, (X_test.columns != 'pnum') & (X_test.columns != 'cond') & (X_test.columns != 'label')]).T)[0]

            if not D or D[-1] == xi:
                yi = xi
            else:
                yi = GAMMA*(1 - yi_1)*xi + DELTA*yi_1*(1 - xi) + yi_1*xi

            Di = 1 if yi >= CLF_THRESHOLD else 0
            D.append(Di)
            yi_1 = yi

        res = filter(lambda x: x[0] != -1, zip(y_test.values, D))
        y_test, y_pred = zip(*res)

        RESULTS_AVAL.append({
            'accuracy': accuracy_score(y_test, y_pred),
            'f1_score': f1_score(y_test, y_pred)
        })
        MODELS_AVAL[test_name] = clf
        TRAIN_SETS_AVAL[test_name] = X_train

    return RESULTS_AVAL

def knn_model(INPUT_DATAFRAME):
    DATA_SET = INPUT_DATAFRAME

    FEATURES = DATA_SET[feature_list]
    LABELS_AVAL = DATA_SET['label']
    PIDS = DATA_SET['pnum']

    RESULTS_AVAL, MODELS_AVAL, TRAIN_SETS_AVAL = [], {}, {}

    splitter = LeaveOneGroupOut()

    for I_train, I_test in splitter.split(FEATURES, LABELS_AVAL, PIDS):    
        X_train, X_test = FEATURES.iloc[I_train], FEATURES.iloc[I_test] 
        y_train, y_test = LABELS_AVAL.iloc[I_train], LABELS_AVAL.iloc[I_test]
        test_name = np.unique(PIDS[I_test])[0]
        
        inner_splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
        I_train, I_eval = next(inner_splitter.split(X_train, y_train))
        X_train, X_eval = X_train.iloc[I_train], X_train.iloc[I_eval]
        y_train, y_eval = y_train.iloc[I_train], y_train.iloc[I_eval]

        clf = KNeighborsClassifier(n_neighbors=9)
        
        clf.fit(X_train, y_train)

        # # General approach
        # y_pred = clf.predict(X_test)
        # y_prob = clf.predict_proba(X_test)[:, 1]

        # Use of V.Mishra's two-layer approach https://dl.acm.org/doi/pdf/10.1145/3361562        
        CLF_THRESHOLD = 0.5
        GAMMA = 0.33
        DELTA = 0.86
        
        D, yi_1 = [], None
        X_test = X_test.reset_index(drop=True)
        for idx in X_test.index:
            xi = clf.predict(pd.DataFrame(X_test.iloc[idx, (X_test.columns != 'pnum') & (X_test.columns != 'cond') & (X_test.columns != 'label')]).T)[0]

            if not D or D[-1] == xi:
                yi = xi
            else:
                yi = GAMMA*(1 - yi_1)*xi + DELTA*yi_1*(1 - xi) + yi_1*xi

            Di = 1 if yi >= CLF_THRESHOLD else 0
            D.append(Di)
            yi_1 = yi

        res = filter(lambda x: x[0] != -1, zip(y_test.values, D))
        y_test, y_pred = zip(*res)

        RESULTS_AVAL.append({
            'accuracy': accuracy_score(y_test, y_pred),
            'f1_score': f1_score(y_test, y_pred)
        })
        MODELS_AVAL[test_name] = clf
        TRAIN_SETS_AVAL[test_name] = X_train

    return RESULTS_AVAL

def svm_model(INPUT_DATAFRAME):
    DATA_SET = INPUT_DATAFRAME

    FEATURES = DATA_SET[feature_list]
    LABELS_AVAL = DATA_SET['label']
    PIDS = DATA_SET['pnum']

    RESULTS_AVAL, MODELS_AVAL, TRAIN_SETS_AVAL = [], {}, {}

    splitter = LeaveOneGroupOut()

    for I_train, I_test in splitter.split(FEATURES, LABELS_AVAL, PIDS):    
        X_train, X_test = FEATURES.iloc[I_train], FEATURES.iloc[I_test] 
        y_train, y_test = LABELS_AVAL.iloc[I_train], LABELS_AVAL.iloc[I_test]
        test_name = np.unique(PIDS[I_test])[0]

        clf = SVC(probability=True, kernel='rbf', C=107, gamma=0.001)
        
        clf.fit(X_train, y_train)

        # # General approach
        # y_pred = clf.predict(X_test)
        # y_prob = clf.predict_proba(X_test)[:, 1]

        # Use of V.Mishra's two-layer approach https://dl.acm.org/doi/pdf/10.1145/3361562        
        CLF_THRESHOLD = 0.5
        GAMMA = 0.33
        DELTA = 0.86
        
        D, yi_1 = [], None
        X_test = X_test.reset_index(drop=True)
        for idx in X_test.index:
            xi = clf.predict(pd.DataFrame(X_test.iloc[idx, (X_test.columns != 'pnum') & (X_test.columns != 'cond') & (X_test.columns != 'label')]).T)[0]

            if not D or D[-1] == xi:
                yi = xi
            else:
                yi = GAMMA*(1 - yi_1)*xi + DELTA*yi_1*(1 - xi) + yi_1*xi

            Di = 1 if yi >= CLF_THRESHOLD else 0
            D.append(Di)
            yi_1 = yi

        res = filter(lambda x: x[0] != -1, zip(y_test.values, D))
        y_test, y_pred = zip(*res)

        RESULTS_AVAL.append({
            'accuracy': accuracy_score(y_test, y_pred),
            'f1_score': f1_score(y_test, y_pred)
        })
        MODELS_AVAL[test_name] = clf
        TRAIN_SETS_AVAL[test_name] = X_train


        RESULTS_AVAL.append({
            'accuracy': accuracy_score(y_test, y_pred),
            'f1_score': f1_score(y_test, y_pred)
        })
        MODELS_AVAL[test_name] = clf
        TRAIN_SETS_AVAL[test_name] = X_train

    return RESULTS_AVAL

def xgb_model(INPUT_DATAFRAME):
    DATA_SET = INPUT_DATAFRAME

    FEATURES = DATA_SET[feature_list]
    LABELS_AVAL = DATA_SET['label']
    PIDS = DATA_SET['pnum']

    RESULTS_AVAL, MODELS_AVAL, TRAIN_SETS_AVAL = [], {}, {}

    splitter = LeaveOneGroupOut()

    for I_train, I_test in splitter.split(FEATURES, LABELS_AVAL, PIDS):    
        X_train, X_test = FEATURES.iloc[I_train], FEATURES.iloc[I_test] 
        y_train, y_test = LABELS_AVAL.iloc[I_train], LABELS_AVAL.iloc[I_test]
        test_name = np.unique(PIDS[I_test])[0]

        inner_splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
        I_train, I_eval = next(inner_splitter.split(X_train, y_train))
        X_train, X_eval = X_train.iloc[I_train], X_train.iloc[I_eval]
        y_train, y_eval = y_train.iloc[I_train], y_train.iloc[I_eval]

        clf = XGBClassifier(objective='binary:logistic', learning_rate=0.1, max_depth=3, n_estimators=100)

        clf.fit(X_train, y_train, eval_set=[(X_eval, y_eval)])

        # # General approach
        # y_pred = clf.predict(X_test)
        # y_prob = clf.predict_proba(X_test)[:, 1]

        # Use of V.Mishra's two-layer approach https://dl.acm.org/doi/pdf/10.1145/3361562        
        CLF_THRESHOLD = 0.5
        GAMMA = 0.33
        DELTA = 0.86
        
        D, yi_1 = [], None
        X_test = X_test.reset_index(drop=True)
        for idx in X_test.index:
            xi = clf.predict(pd.DataFrame(X_test.iloc[idx, (X_test.columns != 'pnum') & (X_test.columns != 'cond') & (X_test.columns != 'label')]).T)[0]

            if not D or D[-1] == xi:
                yi = xi
            else:
                yi = GAMMA*(1 - yi_1)*xi + DELTA*yi_1*(1 - xi) + yi_1*xi

            Di = 1 if yi >= CLF_THRESHOLD else 0
            D.append(Di)
            yi_1 = yi

        res = filter(lambda x: x[0] != -1, zip(y_test.values, D))
        y_test, y_pred = zip(*res)

        RESULTS_AVAL.append({
            'accuracy': accuracy_score(y_test, y_pred),
            'f1_score': f1_score(y_test, y_pred)
        })
        MODELS_AVAL[test_name] = clf
        TRAIN_SETS_AVAL[test_name] = X_train

        print(np.mean(y_pred))

    return RESULTS_AVAL

# %%
RESULTS_DATAFRAME_MV = major_voting(HRV_FEATURES_DATAFRAME_NORMALIZED)
print(pd.DataFrame(RESULTS_DATAFRAME_MV).mean())
print(pd.DataFrame(RESULTS_DATAFRAME_MV).std())
# Out:
# 0.5963375796178344
# 0.5846438482886216
# 0.5872873769024172
# 0.6031483015741508
# 0.5943637916310845
# 0.5296803652968036
# 0.6060606060606061
# 0.6254237288135593
# 0.6109637488947833
# 0.6176991150442478
# 0.6121883656509696
# 0.6199829205807003
# accuracy    0.598982
# f1_score    0.748909
# dtype: float64
# accuracy    0.025315
# f1_score    0.020359
# dtype: float64

# %%
RESULTS_DATAFRAME_DT = dt_model(HRV_FEATURES_DATAFRAME_NORMALIZED)
print(pd.DataFrame(RESULTS_DATAFRAME_DT).mean())
print(pd.DataFrame(RESULTS_DATAFRAME_DT).std())
# Out:
# accuracy    0.731786
# f1_score    0.779600
# dtype: float64
# accuracy    0.165683
# f1_score    0.155150
# dtype: float64

# %%
RESULTS_DATAFRAME_RF = rf_model(HRV_FEATURES_DATAFRAME_NORMALIZED)
print(pd.DataFrame(RESULTS_DATAFRAME_RF).mean())
print(pd.DataFrame(RESULTS_DATAFRAME_RF).std())
# Out:
# accuracy    0.759054
# f1_score    0.795009
# dtype: float64
# accuracy    0.217388
# f1_score    0.208652
# dtype: float64

# %%
RESULTS_DATAFRAME_AB = ab_model(HRV_FEATURES_DATAFRAME_NORMALIZED)
print(pd.DataFrame(RESULTS_DATAFRAME_AB).mean())
print(pd.DataFrame(RESULTS_DATAFRAME_AB).std())
# Out:
# accuracy    0.765375
# f1_score    0.808883
# dtype: float64
# accuracy    0.200081
# f1_score    0.186254
# dtype: float64

# %%
RESULTS_DATAFRAME_LDA = lda_model(HRV_FEATURES_DATAFRAME_NORMALIZED)
print(pd.DataFrame(RESULTS_DATAFRAME_LDA).mean())
print(pd.DataFrame(RESULTS_DATAFRAME_LDA).std())
# Out:
# accuracy    0.756820
# f1_score    0.796696
# dtype: float64
# accuracy    0.250113
# f1_score    0.222733
# dtype: float64

# %%
RESULTS_DATAFRAME_kNN = knn_model(HRV_FEATURES_DATAFRAME_NORMALIZED)
print(pd.DataFrame(RESULTS_DATAFRAME_kNN).mean())
print(pd.DataFrame(RESULTS_DATAFRAME_kNN).std())
# Out:
# accuracy    0.652507
# f1_score    0.708056
# dtype: float64
# accuracy    0.164101
# f1_score    0.166756
# dtype: float64

# %%
RESULTS_DATAFRAME_XGBOOST = svm_model(HRV_FEATURES_DATAFRAME_NORMALIZED)
print(pd.DataFrame(RESULTS_DATAFRAME_XGBOOST).mean())
print(pd.DataFrame(RESULTS_DATAFRAME_XGBOOST).std())
# Out:
# accuracy    0.747666
# f1_score    0.784750
# dtype: float64
# accuracy    0.217345
# f1_score    0.205936
# dtype: float64

# %%
RESULTS_DATAFRAME_XGBOOST = xgb_model(HRV_FEATURES_DATAFRAME_NORMALIZED)
print(pd.DataFrame(RESULTS_DATAFRAME_XGBOOST).mean())
print(pd.DataFrame(RESULTS_DATAFRAME_XGBOOST).std())
# Out:
# [0]	validation_0-logloss:0.63905
# [1]	validation_0-logloss:0.59401
# [2]	validation_0-logloss:0.55683
# [3]	validation_0-logloss:0.52586
# [4]	validation_0-logloss:0.49967
# [5]	validation_0-logloss:0.47896
# [6]	validation_0-logloss:0.46018
# [7]	validation_0-logloss:0.44360
# [8]	validation_0-logloss:0.42662
# [9]	validation_0-logloss:0.41241
# [10]	validation_0-logloss:0.40015
# [11]	validation_0-logloss:0.38639
# [12]	validation_0-logloss:0.37578
# [13]	validation_0-logloss:0.36686
# [14]	validation_0-logloss:0.35879
# [15]	validation_0-logloss:0.35020
# [16]	validation_0-logloss:0.34161
# [17]	validation_0-logloss:0.33592
# [18]	validation_0-logloss:0.32667
# [19]	validation_0-logloss:0.32006
# [20]	validation_0-logloss:0.31343
# [21]	validation_0-logloss:0.30979
# [22]	validation_0-logloss:0.30590
# [23]	validation_0-logloss:0.30185
# [24]	validation_0-logloss:0.29756
# [25]	validation_0-logloss:0.29397
# [26]	validation_0-logloss:0.28701
# [27]	validation_0-logloss:0.28482
# [28]	validation_0-logloss:0.28231
# [29]	validation_0-logloss:0.27925
# [30]	validation_0-logloss:0.27388
# [31]	validation_0-logloss:0.27045
# [32]	validation_0-logloss:0.26874
# [33]	validation_0-logloss:0.26709
# [34]	validation_0-logloss:0.26469
# [35]	validation_0-logloss:0.26200
# [36]	validation_0-logloss:0.25919
# [37]	validation_0-logloss:0.25339
# [38]	validation_0-logloss:0.24787
# [39]	validation_0-logloss:0.24689
# [40]	validation_0-logloss:0.24387
# [41]	validation_0-logloss:0.24215
# [42]	validation_0-logloss:0.24044
# [43]	validation_0-logloss:0.23585
# [44]	validation_0-logloss:0.23505
# [45]	validation_0-logloss:0.23177
# [46]	validation_0-logloss:0.22913
# [47]	validation_0-logloss:0.22412
# [48]	validation_0-logloss:0.22351
# [49]	validation_0-logloss:0.22166
# [50]	validation_0-logloss:0.21800
# [51]	validation_0-logloss:0.21621
# [52]	validation_0-logloss:0.21270
# [53]	validation_0-logloss:0.21045
# [54]	validation_0-logloss:0.20975
# [55]	validation_0-logloss:0.20537
# [56]	validation_0-logloss:0.20337
# [57]	validation_0-logloss:0.20147
# [58]	validation_0-logloss:0.20019
# [59]	validation_0-logloss:0.19917
# [60]	validation_0-logloss:0.19855
# [61]	validation_0-logloss:0.19746
# [62]	validation_0-logloss:0.19583
# [63]	validation_0-logloss:0.19492
# [64]	validation_0-logloss:0.19382
# [65]	validation_0-logloss:0.19271
# [66]	validation_0-logloss:0.19177
# [67]	validation_0-logloss:0.19065
# [68]	validation_0-logloss:0.18940
# [69]	validation_0-logloss:0.18901
# [70]	validation_0-logloss:0.18671
# [71]	validation_0-logloss:0.18556
# [72]	validation_0-logloss:0.18234
# [73]	validation_0-logloss:0.18198
# [74]	validation_0-logloss:0.18121
# [75]	validation_0-logloss:0.18019
# [76]	validation_0-logloss:0.17872
# [77]	validation_0-logloss:0.17736
# [78]	validation_0-logloss:0.17627
# [79]	validation_0-logloss:0.17330
# [80]	validation_0-logloss:0.17157
# [81]	validation_0-logloss:0.17071
# [82]	validation_0-logloss:0.16936
# [83]	validation_0-logloss:0.16905
# [84]	validation_0-logloss:0.16641
# [85]	validation_0-logloss:0.16602
# [86]	validation_0-logloss:0.16519
# [87]	validation_0-logloss:0.16484
# [88]	validation_0-logloss:0.16326
# [89]	validation_0-logloss:0.16215
# [90]	validation_0-logloss:0.16125
# [91]	validation_0-logloss:0.16007
# [92]	validation_0-logloss:0.15857
# [93]	validation_0-logloss:0.15804
# [94]	validation_0-logloss:0.15717
# [95]	validation_0-logloss:0.15692
# [96]	validation_0-logloss:0.15647
# [97]	validation_0-logloss:0.15490
# [98]	validation_0-logloss:0.15450
# [99]	validation_0-logloss:0.15398
# 0.5732484076433121
# [0]	validation_0-logloss:0.63563
# [1]	validation_0-logloss:0.58866
# [2]	validation_0-logloss:0.55496
# [3]	validation_0-logloss:0.52005
# [4]	validation_0-logloss:0.49350
# [5]	validation_0-logloss:0.47161
# [6]	validation_0-logloss:0.45255
# [7]	validation_0-logloss:0.43679
# [8]	validation_0-logloss:0.42171
# [9]	validation_0-logloss:0.40283
# [10]	validation_0-logloss:0.39011
# [11]	validation_0-logloss:0.37992
# [12]	validation_0-logloss:0.36581
# [13]	validation_0-logloss:0.35441
# [14]	validation_0-logloss:0.34575
# [15]	validation_0-logloss:0.33452
# [16]	validation_0-logloss:0.32530
# [17]	validation_0-logloss:0.31940
# [18]	validation_0-logloss:0.31009
# [19]	validation_0-logloss:0.30480
# [20]	validation_0-logloss:0.29692
# [21]	validation_0-logloss:0.28967
# [22]	validation_0-logloss:0.28090
# [23]	validation_0-logloss:0.27714
# [24]	validation_0-logloss:0.27461
# [25]	validation_0-logloss:0.27149
# [26]	validation_0-logloss:0.26716
# [27]	validation_0-logloss:0.26475
# [28]	validation_0-logloss:0.25927
# [29]	validation_0-logloss:0.25691
# [30]	validation_0-logloss:0.25485
# [31]	validation_0-logloss:0.24863
# [32]	validation_0-logloss:0.24444
# [33]	validation_0-logloss:0.24257
# [34]	validation_0-logloss:0.24046
# [35]	validation_0-logloss:0.23556
# [36]	validation_0-logloss:0.23468
# [37]	validation_0-logloss:0.23281
# [38]	validation_0-logloss:0.22943
# [39]	validation_0-logloss:0.22819
# [40]	validation_0-logloss:0.22669
# [41]	validation_0-logloss:0.22582
# [42]	validation_0-logloss:0.22510
# [43]	validation_0-logloss:0.22409
# [44]	validation_0-logloss:0.22254
# [45]	validation_0-logloss:0.22076
# [46]	validation_0-logloss:0.21587
# [47]	validation_0-logloss:0.21522
# [48]	validation_0-logloss:0.21099
# [49]	validation_0-logloss:0.20965
# [50]	validation_0-logloss:0.20883
# [51]	validation_0-logloss:0.20761
# [52]	validation_0-logloss:0.20653
# [53]	validation_0-logloss:0.20226
# [54]	validation_0-logloss:0.20127
# [55]	validation_0-logloss:0.19983
# [56]	validation_0-logloss:0.19776
# [57]	validation_0-logloss:0.19698
# [58]	validation_0-logloss:0.19577
# [59]	validation_0-logloss:0.19426
# [60]	validation_0-logloss:0.19336
# [61]	validation_0-logloss:0.19234
# [62]	validation_0-logloss:0.19192
# [63]	validation_0-logloss:0.19119
# [64]	validation_0-logloss:0.19046
# [65]	validation_0-logloss:0.18939
# [66]	validation_0-logloss:0.18882
# [67]	validation_0-logloss:0.18826
# [68]	validation_0-logloss:0.18747
# [69]	validation_0-logloss:0.18662
# [70]	validation_0-logloss:0.18589
# [71]	validation_0-logloss:0.18492
# [72]	validation_0-logloss:0.18438
# [73]	validation_0-logloss:0.18313
# [74]	validation_0-logloss:0.18227
# [75]	validation_0-logloss:0.17902
# [76]	validation_0-logloss:0.17722
# [77]	validation_0-logloss:0.17671
# [78]	validation_0-logloss:0.17618
# [79]	validation_0-logloss:0.17434
# [80]	validation_0-logloss:0.17386
# [81]	validation_0-logloss:0.17012
# [82]	validation_0-logloss:0.16730
# [83]	validation_0-logloss:0.16585
# [84]	validation_0-logloss:0.16327
# [85]	validation_0-logloss:0.16138
# [86]	validation_0-logloss:0.15910
# [87]	validation_0-logloss:0.15839
# [88]	validation_0-logloss:0.15737
# [89]	validation_0-logloss:0.15643
# [90]	validation_0-logloss:0.15571
# [91]	validation_0-logloss:0.15528
# [92]	validation_0-logloss:0.15408
# [93]	validation_0-logloss:0.15197
# [94]	validation_0-logloss:0.14997
# [95]	validation_0-logloss:0.14871
# [96]	validation_0-logloss:0.14838
# [97]	validation_0-logloss:0.14808
# [98]	validation_0-logloss:0.14763
# [99]	validation_0-logloss:0.14711
# 0.6836262719703978
# [0]	validation_0-logloss:0.63762
# [1]	validation_0-logloss:0.59246
# [2]	validation_0-logloss:0.55665
# [3]	validation_0-logloss:0.52756
# [4]	validation_0-logloss:0.50309
# [5]	validation_0-logloss:0.47784
# [6]	validation_0-logloss:0.45885
# [7]	validation_0-logloss:0.44227
# [8]	validation_0-logloss:0.42711
# [9]	validation_0-logloss:0.41402
# [10]	validation_0-logloss:0.40243
# [11]	validation_0-logloss:0.39158
# [12]	validation_0-logloss:0.37872
# [13]	validation_0-logloss:0.36648
# [14]	validation_0-logloss:0.35872
# [15]	validation_0-logloss:0.34995
# [16]	validation_0-logloss:0.34385
# [17]	validation_0-logloss:0.33469
# [18]	validation_0-logloss:0.32781
# [19]	validation_0-logloss:0.32361
# [20]	validation_0-logloss:0.31610
# [21]	validation_0-logloss:0.31209
# [22]	validation_0-logloss:0.30853
# [23]	validation_0-logloss:0.30591
# [24]	validation_0-logloss:0.30321
# [25]	validation_0-logloss:0.29958
# [26]	validation_0-logloss:0.29695
# [27]	validation_0-logloss:0.29455
# [28]	validation_0-logloss:0.29136
# [29]	validation_0-logloss:0.28899
# [30]	validation_0-logloss:0.27944
# [31]	validation_0-logloss:0.27663
# [32]	validation_0-logloss:0.27535
# [33]	validation_0-logloss:0.26851
# [34]	validation_0-logloss:0.26566
# [35]	validation_0-logloss:0.26469
# [36]	validation_0-logloss:0.26206
# [37]	validation_0-logloss:0.26000
# [38]	validation_0-logloss:0.25891
# [39]	validation_0-logloss:0.25752
# [40]	validation_0-logloss:0.25552
# [41]	validation_0-logloss:0.25269
# [42]	validation_0-logloss:0.25029
# [43]	validation_0-logloss:0.24848
# [44]	validation_0-logloss:0.24761
# [45]	validation_0-logloss:0.24549
# [46]	validation_0-logloss:0.24307
# [47]	validation_0-logloss:0.24115
# [48]	validation_0-logloss:0.23897
# [49]	validation_0-logloss:0.23701
# [50]	validation_0-logloss:0.23610
# [51]	validation_0-logloss:0.23480
# [52]	validation_0-logloss:0.23272
# [53]	validation_0-logloss:0.23096
# [54]	validation_0-logloss:0.23043
# [55]	validation_0-logloss:0.22936
# [56]	validation_0-logloss:0.22466
# [57]	validation_0-logloss:0.22309
# [58]	validation_0-logloss:0.21889
# [59]	validation_0-logloss:0.21802
# [60]	validation_0-logloss:0.21751
# [61]	validation_0-logloss:0.21620
# [62]	validation_0-logloss:0.21475
# [63]	validation_0-logloss:0.21396
# [64]	validation_0-logloss:0.21097
# [65]	validation_0-logloss:0.21052
# [66]	validation_0-logloss:0.20639
# [67]	validation_0-logloss:0.20527
# [68]	validation_0-logloss:0.20467
# [69]	validation_0-logloss:0.20312
# [70]	validation_0-logloss:0.20041
# [71]	validation_0-logloss:0.19890
# [72]	validation_0-logloss:0.19807
# [73]	validation_0-logloss:0.19579
# [74]	validation_0-logloss:0.19248
# [75]	validation_0-logloss:0.19069
# [76]	validation_0-logloss:0.18984
# [77]	validation_0-logloss:0.18899
# [78]	validation_0-logloss:0.18780
# [79]	validation_0-logloss:0.18565
# [80]	validation_0-logloss:0.18491
# [81]	validation_0-logloss:0.18428
# [82]	validation_0-logloss:0.18362
# [83]	validation_0-logloss:0.17909
# [84]	validation_0-logloss:0.17526
# [85]	validation_0-logloss:0.17286
# [86]	validation_0-logloss:0.17144
# [87]	validation_0-logloss:0.17083
# [88]	validation_0-logloss:0.17002
# [89]	validation_0-logloss:0.16951
# [90]	validation_0-logloss:0.16897
# [91]	validation_0-logloss:0.16505
# [92]	validation_0-logloss:0.16143
# [93]	validation_0-logloss:0.16033
# [94]	validation_0-logloss:0.15786
# [95]	validation_0-logloss:0.15642
# [96]	validation_0-logloss:0.15424
# [97]	validation_0-logloss:0.15232
# [98]	validation_0-logloss:0.15168
# [99]	validation_0-logloss:0.14892
# 0.567591763652641
# [0]	validation_0-logloss:0.63320
# [1]	validation_0-logloss:0.58393
# [2]	validation_0-logloss:0.54326
# [3]	validation_0-logloss:0.50892
# [4]	validation_0-logloss:0.48390
# [5]	validation_0-logloss:0.46090
# [6]	validation_0-logloss:0.43799
# [7]	validation_0-logloss:0.41934
# [8]	validation_0-logloss:0.40327
# [9]	validation_0-logloss:0.38625
# [10]	validation_0-logloss:0.37190
# [11]	validation_0-logloss:0.35805
# [12]	validation_0-logloss:0.34793
# [13]	validation_0-logloss:0.33829
# [14]	validation_0-logloss:0.32841
# [15]	validation_0-logloss:0.31886
# [16]	validation_0-logloss:0.31219
# [17]	validation_0-logloss:0.30364
# [18]	validation_0-logloss:0.28913
# [19]	validation_0-logloss:0.28353
# [20]	validation_0-logloss:0.27461
# [21]	validation_0-logloss:0.26972
# [22]	validation_0-logloss:0.26084
# [23]	validation_0-logloss:0.25622
# [24]	validation_0-logloss:0.25382
# [25]	validation_0-logloss:0.25108
# [26]	validation_0-logloss:0.24893
# [27]	validation_0-logloss:0.24485
# [28]	validation_0-logloss:0.24316
# [29]	validation_0-logloss:0.24000
# [30]	validation_0-logloss:0.23874
# [31]	validation_0-logloss:0.23636
# [32]	validation_0-logloss:0.23530
# [33]	validation_0-logloss:0.23408
# [34]	validation_0-logloss:0.23264
# [35]	validation_0-logloss:0.23083
# [36]	validation_0-logloss:0.22391
# [37]	validation_0-logloss:0.22175
# [38]	validation_0-logloss:0.21941
# [39]	validation_0-logloss:0.21856
# [40]	validation_0-logloss:0.21753
# [41]	validation_0-logloss:0.21152
# [42]	validation_0-logloss:0.20849
# [43]	validation_0-logloss:0.20540
# [44]	validation_0-logloss:0.20152
# [45]	validation_0-logloss:0.19915
# [46]	validation_0-logloss:0.19838
# [47]	validation_0-logloss:0.19581
# [48]	validation_0-logloss:0.19243
# [49]	validation_0-logloss:0.19179
# [50]	validation_0-logloss:0.19003
# [51]	validation_0-logloss:0.18864
# [52]	validation_0-logloss:0.18598
# [53]	validation_0-logloss:0.18399
# [54]	validation_0-logloss:0.18197
# [55]	validation_0-logloss:0.18148
# [56]	validation_0-logloss:0.18067
# [57]	validation_0-logloss:0.17864
# [58]	validation_0-logloss:0.17645
# [59]	validation_0-logloss:0.17375
# [60]	validation_0-logloss:0.17136
# [61]	validation_0-logloss:0.17040
# [62]	validation_0-logloss:0.16993
# [63]	validation_0-logloss:0.16867
# [64]	validation_0-logloss:0.16811
# [65]	validation_0-logloss:0.16683
# [66]	validation_0-logloss:0.16627
# [67]	validation_0-logloss:0.16538
# [68]	validation_0-logloss:0.16503
# [69]	validation_0-logloss:0.16433
# [70]	validation_0-logloss:0.16042
# [71]	validation_0-logloss:0.15872
# [72]	validation_0-logloss:0.15643
# [73]	validation_0-logloss:0.15476
# [74]	validation_0-logloss:0.15435
# [75]	validation_0-logloss:0.15404
# [76]	validation_0-logloss:0.15263
# [77]	validation_0-logloss:0.15219
# [78]	validation_0-logloss:0.15020
# [79]	validation_0-logloss:0.14936
# [80]	validation_0-logloss:0.14913
# [81]	validation_0-logloss:0.14878
# [82]	validation_0-logloss:0.14781
# [83]	validation_0-logloss:0.14757
# [84]	validation_0-logloss:0.14584
# [85]	validation_0-logloss:0.14543
# [86]	validation_0-logloss:0.14232
# [87]	validation_0-logloss:0.14179
# [88]	validation_0-logloss:0.14152
# [89]	validation_0-logloss:0.14133
# [90]	validation_0-logloss:0.13785
# [91]	validation_0-logloss:0.13232
# [92]	validation_0-logloss:0.13055
# [93]	validation_0-logloss:0.12635
# [94]	validation_0-logloss:0.12531
# [95]	validation_0-logloss:0.12389
# [96]	validation_0-logloss:0.12364
# [97]	validation_0-logloss:0.12287
# [98]	validation_0-logloss:0.12269
# [99]	validation_0-logloss:0.12175
# 0.5915492957746479
# [0]	validation_0-logloss:0.63373
# [1]	validation_0-logloss:0.58890
# [2]	validation_0-logloss:0.54715
# [3]	validation_0-logloss:0.51291
# [4]	validation_0-logloss:0.48264
# [5]	validation_0-logloss:0.45723
# [6]	validation_0-logloss:0.43655
# [7]	validation_0-logloss:0.42110
# [8]	validation_0-logloss:0.40306
# [9]	validation_0-logloss:0.38629
# [10]	validation_0-logloss:0.37513
# [11]	validation_0-logloss:0.36424
# [12]	validation_0-logloss:0.35320
# [13]	validation_0-logloss:0.34266
# [14]	validation_0-logloss:0.33494
# [15]	validation_0-logloss:0.32682
# [16]	validation_0-logloss:0.31925
# [17]	validation_0-logloss:0.31351
# [18]	validation_0-logloss:0.30259
# [19]	validation_0-logloss:0.29714
# [20]	validation_0-logloss:0.29180
# [21]	validation_0-logloss:0.28770
# [22]	validation_0-logloss:0.28068
# [23]	validation_0-logloss:0.27510
# [24]	validation_0-logloss:0.26752
# [25]	validation_0-logloss:0.26460
# [26]	validation_0-logloss:0.26060
# [27]	validation_0-logloss:0.25697
# [28]	validation_0-logloss:0.25442
# [29]	validation_0-logloss:0.25082
# [30]	validation_0-logloss:0.24768
# [31]	validation_0-logloss:0.24549
# [32]	validation_0-logloss:0.24357
# [33]	validation_0-logloss:0.23785
# [34]	validation_0-logloss:0.23528
# [35]	validation_0-logloss:0.23310
# [36]	validation_0-logloss:0.23133
# [37]	validation_0-logloss:0.22957
# [38]	validation_0-logloss:0.22482
# [39]	validation_0-logloss:0.22353
# [40]	validation_0-logloss:0.22193
# [41]	validation_0-logloss:0.21940
# [42]	validation_0-logloss:0.21792
# [43]	validation_0-logloss:0.21654
# [44]	validation_0-logloss:0.21492
# [45]	validation_0-logloss:0.21264
# [46]	validation_0-logloss:0.21043
# [47]	validation_0-logloss:0.20868
# [48]	validation_0-logloss:0.20718
# [49]	validation_0-logloss:0.20581
# [50]	validation_0-logloss:0.20452
# [51]	validation_0-logloss:0.20352
# [52]	validation_0-logloss:0.20220
# [53]	validation_0-logloss:0.20108
# [54]	validation_0-logloss:0.19897
# [55]	validation_0-logloss:0.19527
# [56]	validation_0-logloss:0.19436
# [57]	validation_0-logloss:0.19348
# [58]	validation_0-logloss:0.19192
# [59]	validation_0-logloss:0.19067
# [60]	validation_0-logloss:0.18915
# [61]	validation_0-logloss:0.18730
# [62]	validation_0-logloss:0.18668
# [63]	validation_0-logloss:0.18592
# [64]	validation_0-logloss:0.18475
# [65]	validation_0-logloss:0.18416
# [66]	validation_0-logloss:0.18318
# [67]	validation_0-logloss:0.18222
# [68]	validation_0-logloss:0.18146
# [69]	validation_0-logloss:0.18042
# [70]	validation_0-logloss:0.17947
# [71]	validation_0-logloss:0.17695
# [72]	validation_0-logloss:0.17639
# [73]	validation_0-logloss:0.17518
# [74]	validation_0-logloss:0.17426
# [75]	validation_0-logloss:0.17129
# [76]	validation_0-logloss:0.17041
# [77]	validation_0-logloss:0.16963
# [78]	validation_0-logloss:0.16926
# [79]	validation_0-logloss:0.16870
# [80]	validation_0-logloss:0.16815
# [81]	validation_0-logloss:0.16689
# [82]	validation_0-logloss:0.16619
# [83]	validation_0-logloss:0.16519
# [84]	validation_0-logloss:0.16255
# [85]	validation_0-logloss:0.15939
# [86]	validation_0-logloss:0.15900
# [87]	validation_0-logloss:0.15848
# [88]	validation_0-logloss:0.15788
# [89]	validation_0-logloss:0.15397
# [90]	validation_0-logloss:0.15360
# [91]	validation_0-logloss:0.15063
# [92]	validation_0-logloss:0.15005
# [93]	validation_0-logloss:0.14895
# [94]	validation_0-logloss:0.14780
# [95]	validation_0-logloss:0.14576
# [96]	validation_0-logloss:0.14468
# [97]	validation_0-logloss:0.14409
# [98]	validation_0-logloss:0.13995
# [99]	validation_0-logloss:0.13884
# 0.7702818104184458
# [0]	validation_0-logloss:0.62835
# [1]	validation_0-logloss:0.57516
# [2]	validation_0-logloss:0.53089
# [3]	validation_0-logloss:0.49325
# [4]	validation_0-logloss:0.46151
# [5]	validation_0-logloss:0.43415
# [6]	validation_0-logloss:0.40891
# [7]	validation_0-logloss:0.38760
# [8]	validation_0-logloss:0.36907
# [9]	validation_0-logloss:0.35235
# [10]	validation_0-logloss:0.33804
# [11]	validation_0-logloss:0.32420
# [12]	validation_0-logloss:0.31107
# [13]	validation_0-logloss:0.29939
# [14]	validation_0-logloss:0.29064
# [15]	validation_0-logloss:0.28293
# [16]	validation_0-logloss:0.27568
# [17]	validation_0-logloss:0.26774
# [18]	validation_0-logloss:0.26135
# [19]	validation_0-logloss:0.25558
# [20]	validation_0-logloss:0.25010
# [21]	validation_0-logloss:0.24503
# [22]	validation_0-logloss:0.23740
# [23]	validation_0-logloss:0.23335
# [24]	validation_0-logloss:0.22733
# [25]	validation_0-logloss:0.22327
# [26]	validation_0-logloss:0.21882
# [27]	validation_0-logloss:0.21546
# [28]	validation_0-logloss:0.21189
# [29]	validation_0-logloss:0.20908
# [30]	validation_0-logloss:0.20498
# [31]	validation_0-logloss:0.20302
# [32]	validation_0-logloss:0.20066
# [33]	validation_0-logloss:0.19788
# [34]	validation_0-logloss:0.19637
# [35]	validation_0-logloss:0.19291
# [36]	validation_0-logloss:0.19097
# [37]	validation_0-logloss:0.18927
# [38]	validation_0-logloss:0.18756
# [39]	validation_0-logloss:0.18507
# [40]	validation_0-logloss:0.18371
# [41]	validation_0-logloss:0.18285
# [42]	validation_0-logloss:0.18042
# [43]	validation_0-logloss:0.17694
# [44]	validation_0-logloss:0.17263
# [45]	validation_0-logloss:0.17219
# [46]	validation_0-logloss:0.17046
# [47]	validation_0-logloss:0.16991
# [48]	validation_0-logloss:0.16885
# [49]	validation_0-logloss:0.16721
# [50]	validation_0-logloss:0.16584
# [51]	validation_0-logloss:0.16268
# [52]	validation_0-logloss:0.16091
# [53]	validation_0-logloss:0.16021
# [54]	validation_0-logloss:0.15885
# [55]	validation_0-logloss:0.15692
# [56]	validation_0-logloss:0.15589
# [57]	validation_0-logloss:0.15468
# [58]	validation_0-logloss:0.15228
# [59]	validation_0-logloss:0.15172
# [60]	validation_0-logloss:0.15131
# [61]	validation_0-logloss:0.14852
# [62]	validation_0-logloss:0.14491
# [63]	validation_0-logloss:0.14384
# [64]	validation_0-logloss:0.14124
# [65]	validation_0-logloss:0.14055
# [66]	validation_0-logloss:0.13952
# [67]	validation_0-logloss:0.13810
# [68]	validation_0-logloss:0.13764
# [69]	validation_0-logloss:0.13648
# [70]	validation_0-logloss:0.13520
# [71]	validation_0-logloss:0.13167
# [72]	validation_0-logloss:0.13109
# [73]	validation_0-logloss:0.13073
# [74]	validation_0-logloss:0.12810
# [75]	validation_0-logloss:0.12765
# [76]	validation_0-logloss:0.12701
# [77]	validation_0-logloss:0.12666
# [78]	validation_0-logloss:0.12325
# [79]	validation_0-logloss:0.12214
# [80]	validation_0-logloss:0.12136
# [81]	validation_0-logloss:0.12072
# [82]	validation_0-logloss:0.12007
# [83]	validation_0-logloss:0.11872
# [84]	validation_0-logloss:0.11823
# [85]	validation_0-logloss:0.11738
# [86]	validation_0-logloss:0.11664
# [87]	validation_0-logloss:0.11600
# [88]	validation_0-logloss:0.11535
# [89]	validation_0-logloss:0.11305
# [90]	validation_0-logloss:0.11194
# [91]	validation_0-logloss:0.10964
# [92]	validation_0-logloss:0.10944
# [93]	validation_0-logloss:0.10873
# [94]	validation_0-logloss:0.10844
# [95]	validation_0-logloss:0.10633
# [96]	validation_0-logloss:0.10568
# [97]	validation_0-logloss:0.10498
# [98]	validation_0-logloss:0.10428
# [99]	validation_0-logloss:0.10404
# 0.4878234398782344
# [0]	validation_0-logloss:0.63094
# [1]	validation_0-logloss:0.58046
# [2]	validation_0-logloss:0.53815
# [3]	validation_0-logloss:0.50416
# [4]	validation_0-logloss:0.47280
# [5]	validation_0-logloss:0.44788
# [6]	validation_0-logloss:0.42449
# [7]	validation_0-logloss:0.40595
# [8]	validation_0-logloss:0.38811
# [9]	validation_0-logloss:0.37218
# [10]	validation_0-logloss:0.35728
# [11]	validation_0-logloss:0.34604
# [12]	validation_0-logloss:0.33408
# [13]	validation_0-logloss:0.32414
# [14]	validation_0-logloss:0.31419
# [15]	validation_0-logloss:0.30541
# [16]	validation_0-logloss:0.29785
# [17]	validation_0-logloss:0.28980
# [18]	validation_0-logloss:0.28352
# [19]	validation_0-logloss:0.27694
# [20]	validation_0-logloss:0.27061
# [21]	validation_0-logloss:0.26528
# [22]	validation_0-logloss:0.25774
# [23]	validation_0-logloss:0.25321
# [24]	validation_0-logloss:0.24728
# [25]	validation_0-logloss:0.24319
# [26]	validation_0-logloss:0.23775
# [27]	validation_0-logloss:0.23106
# [28]	validation_0-logloss:0.22846
# [29]	validation_0-logloss:0.22394
# [30]	validation_0-logloss:0.22175
# [31]	validation_0-logloss:0.21664
# [32]	validation_0-logloss:0.21448
# [33]	validation_0-logloss:0.21267
# [34]	validation_0-logloss:0.21061
# [35]	validation_0-logloss:0.20707
# [36]	validation_0-logloss:0.20586
# [37]	validation_0-logloss:0.20250
# [38]	validation_0-logloss:0.19818
# [39]	validation_0-logloss:0.19667
# [40]	validation_0-logloss:0.19348
# [41]	validation_0-logloss:0.19196
# [42]	validation_0-logloss:0.19093
# [43]	validation_0-logloss:0.18937
# [44]	validation_0-logloss:0.18787
# [45]	validation_0-logloss:0.18707
# [46]	validation_0-logloss:0.18577
# [47]	validation_0-logloss:0.18460
# [48]	validation_0-logloss:0.18241
# [49]	validation_0-logloss:0.18116
# [50]	validation_0-logloss:0.17937
# [51]	validation_0-logloss:0.17868
# [52]	validation_0-logloss:0.17633
# [53]	validation_0-logloss:0.17404
# [54]	validation_0-logloss:0.17045
# [55]	validation_0-logloss:0.16883
# [56]	validation_0-logloss:0.16688
# [57]	validation_0-logloss:0.16269
# [58]	validation_0-logloss:0.16125
# [59]	validation_0-logloss:0.15976
# [60]	validation_0-logloss:0.15904
# [61]	validation_0-logloss:0.15599
# [62]	validation_0-logloss:0.15511
# [63]	validation_0-logloss:0.15363
# [64]	validation_0-logloss:0.15248
# [65]	validation_0-logloss:0.15092
# [66]	validation_0-logloss:0.14786
# [67]	validation_0-logloss:0.14676
# [68]	validation_0-logloss:0.14573
# [69]	validation_0-logloss:0.14476
# [70]	validation_0-logloss:0.14402
# [71]	validation_0-logloss:0.14130
# [72]	validation_0-logloss:0.14043
# [73]	validation_0-logloss:0.13976
# [74]	validation_0-logloss:0.13907
# [75]	validation_0-logloss:0.13771
# [76]	validation_0-logloss:0.13564
# [77]	validation_0-logloss:0.13488
# [78]	validation_0-logloss:0.13395
# [79]	validation_0-logloss:0.13349
# [80]	validation_0-logloss:0.13240
# [81]	validation_0-logloss:0.13024
# [82]	validation_0-logloss:0.12990
# [83]	validation_0-logloss:0.12903
# [84]	validation_0-logloss:0.12717
# [85]	validation_0-logloss:0.12602
# [86]	validation_0-logloss:0.12481
# [87]	validation_0-logloss:0.12256
# [88]	validation_0-logloss:0.12111
# [89]	validation_0-logloss:0.12046
# [90]	validation_0-logloss:0.11904
# [91]	validation_0-logloss:0.11839
# [92]	validation_0-logloss:0.11721
# [93]	validation_0-logloss:0.11611
# [94]	validation_0-logloss:0.11284
# [95]	validation_0-logloss:0.11209
# [96]	validation_0-logloss:0.11119
# [97]	validation_0-logloss:0.10949
# [98]	validation_0-logloss:0.10884
# [99]	validation_0-logloss:0.10636
# 0.5956709956709957
# [0]	validation_0-logloss:0.63166
# [1]	validation_0-logloss:0.58146
# [2]	validation_0-logloss:0.53971
# [3]	validation_0-logloss:0.50391
# [4]	validation_0-logloss:0.47474
# [5]	validation_0-logloss:0.44971
# [6]	validation_0-logloss:0.42614
# [7]	validation_0-logloss:0.40759
# [8]	validation_0-logloss:0.39006
# [9]	validation_0-logloss:0.37437
# [10]	validation_0-logloss:0.36151
# [11]	validation_0-logloss:0.34815
# [12]	validation_0-logloss:0.33627
# [13]	validation_0-logloss:0.32571
# [14]	validation_0-logloss:0.31620
# [15]	validation_0-logloss:0.30727
# [16]	validation_0-logloss:0.29948
# [17]	validation_0-logloss:0.29216
# [18]	validation_0-logloss:0.28348
# [19]	validation_0-logloss:0.27675
# [20]	validation_0-logloss:0.27121
# [21]	validation_0-logloss:0.26519
# [22]	validation_0-logloss:0.26023
# [23]	validation_0-logloss:0.25311
# [24]	validation_0-logloss:0.24806
# [25]	validation_0-logloss:0.24340
# [26]	validation_0-logloss:0.24034
# [27]	validation_0-logloss:0.23782
# [28]	validation_0-logloss:0.23509
# [29]	validation_0-logloss:0.23067
# [30]	validation_0-logloss:0.22877
# [31]	validation_0-logloss:0.22681
# [32]	validation_0-logloss:0.22002
# [33]	validation_0-logloss:0.21750
# [34]	validation_0-logloss:0.21638
# [35]	validation_0-logloss:0.21472
# [36]	validation_0-logloss:0.20938
# [37]	validation_0-logloss:0.20736
# [38]	validation_0-logloss:0.20622
# [39]	validation_0-logloss:0.20287
# [40]	validation_0-logloss:0.19792
# [41]	validation_0-logloss:0.19657
# [42]	validation_0-logloss:0.19297
# [43]	validation_0-logloss:0.18904
# [44]	validation_0-logloss:0.18799
# [45]	validation_0-logloss:0.18626
# [46]	validation_0-logloss:0.18542
# [47]	validation_0-logloss:0.18441
# [48]	validation_0-logloss:0.18111
# [49]	validation_0-logloss:0.17877
# [50]	validation_0-logloss:0.17584
# [51]	validation_0-logloss:0.17372
# [52]	validation_0-logloss:0.17233
# [53]	validation_0-logloss:0.16987
# [54]	validation_0-logloss:0.16738
# [55]	validation_0-logloss:0.16549
# [56]	validation_0-logloss:0.16403
# [57]	validation_0-logloss:0.16272
# [58]	validation_0-logloss:0.16177
# [59]	validation_0-logloss:0.16077
# [60]	validation_0-logloss:0.15922
# [61]	validation_0-logloss:0.15843
# [62]	validation_0-logloss:0.15723
# [63]	validation_0-logloss:0.15518
# [64]	validation_0-logloss:0.15389
# [65]	validation_0-logloss:0.15292
# [66]	validation_0-logloss:0.15177
# [67]	validation_0-logloss:0.15064
# [68]	validation_0-logloss:0.15011
# [69]	validation_0-logloss:0.14918
# [70]	validation_0-logloss:0.14746
# [71]	validation_0-logloss:0.14567
# [72]	validation_0-logloss:0.14322
# [73]	validation_0-logloss:0.14185
# [74]	validation_0-logloss:0.14102
# [75]	validation_0-logloss:0.13978
# [76]	validation_0-logloss:0.13919
# [77]	validation_0-logloss:0.13770
# [78]	validation_0-logloss:0.13587
# [79]	validation_0-logloss:0.13525
# [80]	validation_0-logloss:0.13451
# [81]	validation_0-logloss:0.13308
# [82]	validation_0-logloss:0.13225
# [83]	validation_0-logloss:0.13126
# [84]	validation_0-logloss:0.13074
# [85]	validation_0-logloss:0.12840
# [86]	validation_0-logloss:0.12746
# [87]	validation_0-logloss:0.12570
# [88]	validation_0-logloss:0.12522
# [89]	validation_0-logloss:0.12469
# [90]	validation_0-logloss:0.12200
# [91]	validation_0-logloss:0.12072
# [92]	validation_0-logloss:0.11986
# [93]	validation_0-logloss:0.11946
# [94]	validation_0-logloss:0.11921
# [95]	validation_0-logloss:0.11886
# [96]	validation_0-logloss:0.11769
# [97]	validation_0-logloss:0.11736
# [98]	validation_0-logloss:0.11697
# [99]	validation_0-logloss:0.11664
# 0.5161016949152543
# [0]	validation_0-logloss:0.63645
# [1]	validation_0-logloss:0.58966
# [2]	validation_0-logloss:0.55032
# [3]	validation_0-logloss:0.51739
# [4]	validation_0-logloss:0.48895
# [5]	validation_0-logloss:0.46798
# [6]	validation_0-logloss:0.45110
# [7]	validation_0-logloss:0.43075
# [8]	validation_0-logloss:0.41571
# [9]	validation_0-logloss:0.40393
# [10]	validation_0-logloss:0.39011
# [11]	validation_0-logloss:0.37653
# [12]	validation_0-logloss:0.36550
# [13]	validation_0-logloss:0.35513
# [14]	validation_0-logloss:0.34637
# [15]	validation_0-logloss:0.33569
# [16]	validation_0-logloss:0.32836
# [17]	validation_0-logloss:0.31923
# [18]	validation_0-logloss:0.31288
# [19]	validation_0-logloss:0.30505
# [20]	validation_0-logloss:0.29965
# [21]	validation_0-logloss:0.29059
# [22]	validation_0-logloss:0.28452
# [23]	validation_0-logloss:0.28040
# [24]	validation_0-logloss:0.27713
# [25]	validation_0-logloss:0.27332
# [26]	validation_0-logloss:0.26822
# [27]	validation_0-logloss:0.26435
# [28]	validation_0-logloss:0.25690
# [29]	validation_0-logloss:0.25487
# [30]	validation_0-logloss:0.25121
# [31]	validation_0-logloss:0.24833
# [32]	validation_0-logloss:0.24601
# [33]	validation_0-logloss:0.24491
# [34]	validation_0-logloss:0.24398
# [35]	validation_0-logloss:0.24157
# [36]	validation_0-logloss:0.23849
# [37]	validation_0-logloss:0.23711
# [38]	validation_0-logloss:0.23414
# [39]	validation_0-logloss:0.23341
# [40]	validation_0-logloss:0.23199
# [41]	validation_0-logloss:0.22896
# [42]	validation_0-logloss:0.22699
# [43]	validation_0-logloss:0.22037
# [44]	validation_0-logloss:0.21795
# [45]	validation_0-logloss:0.21616
# [46]	validation_0-logloss:0.21300
# [47]	validation_0-logloss:0.21076
# [48]	validation_0-logloss:0.20862
# [49]	validation_0-logloss:0.20670
# [50]	validation_0-logloss:0.20512
# [51]	validation_0-logloss:0.20291
# [52]	validation_0-logloss:0.20088
# [53]	validation_0-logloss:0.20039
# [54]	validation_0-logloss:0.19940
# [55]	validation_0-logloss:0.19752
# [56]	validation_0-logloss:0.19611
# [57]	validation_0-logloss:0.19494
# [58]	validation_0-logloss:0.19326
# [59]	validation_0-logloss:0.19143
# [60]	validation_0-logloss:0.18958
# [61]	validation_0-logloss:0.18891
# [62]	validation_0-logloss:0.18752
# [63]	validation_0-logloss:0.18554
# [64]	validation_0-logloss:0.18370
# [65]	validation_0-logloss:0.18250
# [66]	validation_0-logloss:0.18168
# [67]	validation_0-logloss:0.18024
# [68]	validation_0-logloss:0.17961
# [69]	validation_0-logloss:0.17918
# [70]	validation_0-logloss:0.17805
# [71]	validation_0-logloss:0.17669
# [72]	validation_0-logloss:0.17218
# [73]	validation_0-logloss:0.17121
# [74]	validation_0-logloss:0.16817
# [75]	validation_0-logloss:0.16405
# [76]	validation_0-logloss:0.16198
# [77]	validation_0-logloss:0.16092
# [78]	validation_0-logloss:0.15741
# [79]	validation_0-logloss:0.15590
# [80]	validation_0-logloss:0.15486
# [81]	validation_0-logloss:0.15461
# [82]	validation_0-logloss:0.15361
# [83]	validation_0-logloss:0.15236
# [84]	validation_0-logloss:0.15165
# [85]	validation_0-logloss:0.14826
# [86]	validation_0-logloss:0.14604
# [87]	validation_0-logloss:0.14374
# [88]	validation_0-logloss:0.14338
# [89]	validation_0-logloss:0.14279
# [90]	validation_0-logloss:0.14221
# [91]	validation_0-logloss:0.14144
# [92]	validation_0-logloss:0.14029
# [93]	validation_0-logloss:0.13876
# [94]	validation_0-logloss:0.13797
# [95]	validation_0-logloss:0.13705
# [96]	validation_0-logloss:0.13612
# [97]	validation_0-logloss:0.13564
# [98]	validation_0-logloss:0.13515
# [99]	validation_0-logloss:0.13425
# 0.6312997347480106
# [0]	validation_0-logloss:0.63910
# [1]	validation_0-logloss:0.59473
# [2]	validation_0-logloss:0.55753
# [3]	validation_0-logloss:0.52560
# [4]	validation_0-logloss:0.50122
# [5]	validation_0-logloss:0.48064
# [6]	validation_0-logloss:0.45967
# [7]	validation_0-logloss:0.44342
# [8]	validation_0-logloss:0.42644
# [9]	validation_0-logloss:0.41266
# [10]	validation_0-logloss:0.39998
# [11]	validation_0-logloss:0.38888
# [12]	validation_0-logloss:0.37646
# [13]	validation_0-logloss:0.36469
# [14]	validation_0-logloss:0.35569
# [15]	validation_0-logloss:0.34773
# [16]	validation_0-logloss:0.33866
# [17]	validation_0-logloss:0.33043
# [18]	validation_0-logloss:0.32405
# [19]	validation_0-logloss:0.31602
# [20]	validation_0-logloss:0.30974
# [21]	validation_0-logloss:0.30464
# [22]	validation_0-logloss:0.29784
# [23]	validation_0-logloss:0.29274
# [24]	validation_0-logloss:0.28938
# [25]	validation_0-logloss:0.28399
# [26]	validation_0-logloss:0.28145
# [27]	validation_0-logloss:0.27276
# [28]	validation_0-logloss:0.26978
# [29]	validation_0-logloss:0.26419
# [30]	validation_0-logloss:0.26220
# [31]	validation_0-logloss:0.25657
# [32]	validation_0-logloss:0.25409
# [33]	validation_0-logloss:0.25257
# [34]	validation_0-logloss:0.25116
# [35]	validation_0-logloss:0.24916
# [36]	validation_0-logloss:0.24747
# [37]	validation_0-logloss:0.24507
# [38]	validation_0-logloss:0.24175
# [39]	validation_0-logloss:0.24059
# [40]	validation_0-logloss:0.23862
# [41]	validation_0-logloss:0.23745
# [42]	validation_0-logloss:0.23642
# [43]	validation_0-logloss:0.23431
# [44]	validation_0-logloss:0.23095
# [45]	validation_0-logloss:0.22672
# [46]	validation_0-logloss:0.22385
# [47]	validation_0-logloss:0.22166
# [48]	validation_0-logloss:0.21961
# [49]	validation_0-logloss:0.21608
# [50]	validation_0-logloss:0.21499
# [51]	validation_0-logloss:0.21367
# [52]	validation_0-logloss:0.20966
# [53]	validation_0-logloss:0.20718
# [54]	validation_0-logloss:0.20617
# [55]	validation_0-logloss:0.20503
# [56]	validation_0-logloss:0.20339
# [57]	validation_0-logloss:0.20039
# [58]	validation_0-logloss:0.19950
# [59]	validation_0-logloss:0.19812
# [60]	validation_0-logloss:0.19715
# [61]	validation_0-logloss:0.19640
# [62]	validation_0-logloss:0.19455
# [63]	validation_0-logloss:0.19161
# [64]	validation_0-logloss:0.19078
# [65]	validation_0-logloss:0.19033
# [66]	validation_0-logloss:0.18902
# [67]	validation_0-logloss:0.18840
# [68]	validation_0-logloss:0.18449
# [69]	validation_0-logloss:0.18323
# [70]	validation_0-logloss:0.18206
# [71]	validation_0-logloss:0.18148
# [72]	validation_0-logloss:0.18024
# [73]	validation_0-logloss:0.17667
# [74]	validation_0-logloss:0.17563
# [75]	validation_0-logloss:0.17466
# [76]	validation_0-logloss:0.17375
# [77]	validation_0-logloss:0.17294
# [78]	validation_0-logloss:0.17212
# [79]	validation_0-logloss:0.17128
# [80]	validation_0-logloss:0.16846
# [81]	validation_0-logloss:0.16772
# [82]	validation_0-logloss:0.16740
# [83]	validation_0-logloss:0.16570
# [84]	validation_0-logloss:0.16489
# [85]	validation_0-logloss:0.16403
# [86]	validation_0-logloss:0.16319
# [87]	validation_0-logloss:0.16249
# [88]	validation_0-logloss:0.16090
# [89]	validation_0-logloss:0.16053
# [90]	validation_0-logloss:0.16017
# [91]	validation_0-logloss:0.15752
# [92]	validation_0-logloss:0.15630
# [93]	validation_0-logloss:0.15454
# [94]	validation_0-logloss:0.15311
# [95]	validation_0-logloss:0.15203
# [96]	validation_0-logloss:0.15172
# [97]	validation_0-logloss:0.14870
# [98]	validation_0-logloss:0.14795
# [99]	validation_0-logloss:0.14733
# 0.6168141592920354
# [0]	validation_0-logloss:0.62673
# [1]	validation_0-logloss:0.57476
# [2]	validation_0-logloss:0.53471
# [3]	validation_0-logloss:0.50097
# [4]	validation_0-logloss:0.46771
# [5]	validation_0-logloss:0.44751
# [6]	validation_0-logloss:0.42128
# [7]	validation_0-logloss:0.40104
# [8]	validation_0-logloss:0.38361
# [9]	validation_0-logloss:0.36686
# [10]	validation_0-logloss:0.35190
# [11]	validation_0-logloss:0.33869
# [12]	validation_0-logloss:0.32758
# [13]	validation_0-logloss:0.31659
# [14]	validation_0-logloss:0.30657
# [15]	validation_0-logloss:0.29725
# [16]	validation_0-logloss:0.28888
# [17]	validation_0-logloss:0.28129
# [18]	validation_0-logloss:0.27410
# [19]	validation_0-logloss:0.26562
# [20]	validation_0-logloss:0.25867
# [21]	validation_0-logloss:0.24973
# [22]	validation_0-logloss:0.24444
# [23]	validation_0-logloss:0.24039
# [24]	validation_0-logloss:0.23359
# [25]	validation_0-logloss:0.22990
# [26]	validation_0-logloss:0.22417
# [27]	validation_0-logloss:0.22131
# [28]	validation_0-logloss:0.21842
# [29]	validation_0-logloss:0.21355
# [30]	validation_0-logloss:0.21067
# [31]	validation_0-logloss:0.20626
# [32]	validation_0-logloss:0.20219
# [33]	validation_0-logloss:0.20026
# [34]	validation_0-logloss:0.19654
# [35]	validation_0-logloss:0.19436
# [36]	validation_0-logloss:0.19086
# [37]	validation_0-logloss:0.18895
# [38]	validation_0-logloss:0.18583
# [39]	validation_0-logloss:0.18378
# [40]	validation_0-logloss:0.18184
# [41]	validation_0-logloss:0.17999
# [42]	validation_0-logloss:0.17830
# [43]	validation_0-logloss:0.17570
# [44]	validation_0-logloss:0.17472
# [45]	validation_0-logloss:0.17378
# [46]	validation_0-logloss:0.17292
# [47]	validation_0-logloss:0.17209
# [48]	validation_0-logloss:0.17003
# [49]	validation_0-logloss:0.16898
# [50]	validation_0-logloss:0.16781
# [51]	validation_0-logloss:0.16646
# [52]	validation_0-logloss:0.16303
# [53]	validation_0-logloss:0.16035
# [54]	validation_0-logloss:0.15960
# [55]	validation_0-logloss:0.15847
# [56]	validation_0-logloss:0.15792
# [57]	validation_0-logloss:0.15682
# [58]	validation_0-logloss:0.15611
# [59]	validation_0-logloss:0.15514
# [60]	validation_0-logloss:0.15469
# [61]	validation_0-logloss:0.15180
# [62]	validation_0-logloss:0.15122
# [63]	validation_0-logloss:0.14874
# [64]	validation_0-logloss:0.14580
# [65]	validation_0-logloss:0.14526
# [66]	validation_0-logloss:0.14439
# [67]	validation_0-logloss:0.14335
# [68]	validation_0-logloss:0.14253
# [69]	validation_0-logloss:0.14179
# [70]	validation_0-logloss:0.14075
# [71]	validation_0-logloss:0.13712
# [72]	validation_0-logloss:0.13639
# [73]	validation_0-logloss:0.13482
# [74]	validation_0-logloss:0.13275
# [75]	validation_0-logloss:0.13169
# [76]	validation_0-logloss:0.13078
# [77]	validation_0-logloss:0.12927
# [78]	validation_0-logloss:0.12731
# [79]	validation_0-logloss:0.12638
# [80]	validation_0-logloss:0.12551
# [81]	validation_0-logloss:0.12466
# [82]	validation_0-logloss:0.12386
# [83]	validation_0-logloss:0.12288
# [84]	validation_0-logloss:0.12261
# [85]	validation_0-logloss:0.12174
# [86]	validation_0-logloss:0.12135
# [87]	validation_0-logloss:0.12084
# [88]	validation_0-logloss:0.12064
# [89]	validation_0-logloss:0.11980
# [90]	validation_0-logloss:0.11717
# [91]	validation_0-logloss:0.11670
# [92]	validation_0-logloss:0.11517
# [93]	validation_0-logloss:0.11439
# [94]	validation_0-logloss:0.11370
# [95]	validation_0-logloss:0.11316
# [96]	validation_0-logloss:0.11271
# [97]	validation_0-logloss:0.11056
# [98]	validation_0-logloss:0.10927
# [99]	validation_0-logloss:0.10910
# 0.6897506925207756
# [0]	validation_0-logloss:0.63832
# [1]	validation_0-logloss:0.59366
# [2]	validation_0-logloss:0.55950
# [3]	validation_0-logloss:0.52908
# [4]	validation_0-logloss:0.50459
# [5]	validation_0-logloss:0.47911
# [6]	validation_0-logloss:0.46032
# [7]	validation_0-logloss:0.44375
# [8]	validation_0-logloss:0.42727
# [9]	validation_0-logloss:0.40951
# [10]	validation_0-logloss:0.39835
# [11]	validation_0-logloss:0.38635
# [12]	validation_0-logloss:0.37534
# [13]	validation_0-logloss:0.36703
# [14]	validation_0-logloss:0.35505
# [15]	validation_0-logloss:0.34521
# [16]	validation_0-logloss:0.33544
# [17]	validation_0-logloss:0.32787
# [18]	validation_0-logloss:0.31983
# [19]	validation_0-logloss:0.31458
# [20]	validation_0-logloss:0.30683
# [21]	validation_0-logloss:0.30235
# [22]	validation_0-logloss:0.29744
# [23]	validation_0-logloss:0.29440
# [24]	validation_0-logloss:0.29169
# [25]	validation_0-logloss:0.28813
# [26]	validation_0-logloss:0.28532
# [27]	validation_0-logloss:0.28282
# [28]	validation_0-logloss:0.28092
# [29]	validation_0-logloss:0.27887
# [30]	validation_0-logloss:0.26905
# [31]	validation_0-logloss:0.26693
# [32]	validation_0-logloss:0.26172
# [33]	validation_0-logloss:0.25449
# [34]	validation_0-logloss:0.25023
# [35]	validation_0-logloss:0.24865
# [36]	validation_0-logloss:0.24684
# [37]	validation_0-logloss:0.24075
# [38]	validation_0-logloss:0.23873
# [39]	validation_0-logloss:0.23357
# [40]	validation_0-logloss:0.23078
# [41]	validation_0-logloss:0.22995
# [42]	validation_0-logloss:0.22780
# [43]	validation_0-logloss:0.22345
# [44]	validation_0-logloss:0.22220
# [45]	validation_0-logloss:0.22076
# [46]	validation_0-logloss:0.21795
# [47]	validation_0-logloss:0.21573
# [48]	validation_0-logloss:0.21416
# [49]	validation_0-logloss:0.21208
# [50]	validation_0-logloss:0.21135
# [51]	validation_0-logloss:0.20956
# [52]	validation_0-logloss:0.20715
# [53]	validation_0-logloss:0.20617
# [54]	validation_0-logloss:0.20441
# [55]	validation_0-logloss:0.20196
# [56]	validation_0-logloss:0.19982
# [57]	validation_0-logloss:0.19815
# [58]	validation_0-logloss:0.19724
# [59]	validation_0-logloss:0.19218
# [60]	validation_0-logloss:0.18913
# [61]	validation_0-logloss:0.18765
# [62]	validation_0-logloss:0.18564
# [63]	validation_0-logloss:0.18135
# [64]	validation_0-logloss:0.17854
# [65]	validation_0-logloss:0.17592
# [66]	validation_0-logloss:0.17519
# [67]	validation_0-logloss:0.17410
# [68]	validation_0-logloss:0.17187
# [69]	validation_0-logloss:0.17125
# [70]	validation_0-logloss:0.16981
# [71]	validation_0-logloss:0.16864
# [72]	validation_0-logloss:0.16526
# [73]	validation_0-logloss:0.16387
# [74]	validation_0-logloss:0.16331
# [75]	validation_0-logloss:0.16227
# [76]	validation_0-logloss:0.16006
# [77]	validation_0-logloss:0.15893
# [78]	validation_0-logloss:0.15806
# [79]	validation_0-logloss:0.15674
# [80]	validation_0-logloss:0.15588
# [81]	validation_0-logloss:0.15391
# [82]	validation_0-logloss:0.15328
# [83]	validation_0-logloss:0.15256
# [84]	validation_0-logloss:0.15176
# [85]	validation_0-logloss:0.15117
# [86]	validation_0-logloss:0.14955
# [87]	validation_0-logloss:0.14881
# [88]	validation_0-logloss:0.14692
# [89]	validation_0-logloss:0.14648
# [90]	validation_0-logloss:0.14428
# [91]	validation_0-logloss:0.14306
# [92]	validation_0-logloss:0.14066
# [93]	validation_0-logloss:0.14006
# [94]	validation_0-logloss:0.13965
# [95]	validation_0-logloss:0.13861
# [96]	validation_0-logloss:0.13802
# [97]	validation_0-logloss:0.13773
# [98]	validation_0-logloss:0.13608
# [99]	validation_0-logloss:0.13555
# 0.8266438941076003
# accuracy    0.766821
# f1_score    0.802727
# dtype: float64
# accuracy    0.203142
# f1_score    0.196320
# dtype: float64

# %%
# clf = XGBClassifier(objective='binary:logistic', learning_rate=0.01, max_depth=3, n_estimators=100)

# accuracy    0.760221
# f1_score    0.798257
